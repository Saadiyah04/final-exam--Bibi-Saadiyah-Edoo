# %% [markdown]
# <a href="https://colab.research.google.com/github/Saadiyah04/final-exam--Bibi-Saadiyah-Edoo/blob/main/Task__Manager_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Section 1 – Iterative Prompt Engineering for Task Manager App
# 1.1 Initial Prompt & Pseudocode (8 marks)
# Initial Prompt:
# "Design a CLI-based task manager application using only basic Python concepts from an introductory course, including simple lists and dictionaries, functions, while loops, and basic error handling. Provide structured pseudocode following course planning principles."
# AI Response:
# 1. Start
#
# 2. Define an empty list called tasks
#
# 3. Define function add_task(task):
#    a. Append task to tasks
#    b. Display confirmation
#
# 4. Define function remove_task(index):
#    a. Check if index is valid
#    b. If valid, remove task
#    c. Else, display error
#
# 5. Define function list_tasks():
#    a. If tasks is empty, display message
#    b. Else, loop and display each task
#
# 6. Define function display_menu():
#    a. Print options: Add, List, Remove, Exit
#
# 7. Define main():
#    a. Use while loop for menu
#    b. Get user input
#    c. Call appropriate function based on choice
#    d. Loop until exit
#
# 8. Call main()
# **Course Reference:**
# "I used the planning method from Week 4: Unlocking Reusability – Functions & Modules, which focused on structuring programs into logical, reusable parts."
#
#
# 1.2 Two Prompt Refinements (12 marks)
#
# First Refinement
# Refined Prompt:
# "Expand the CLI task manager pseudocode to include user input validation and a numbered menu system. Ensure all steps use logic from an introductory course, especially loops, functions, and input handling."
#
# AI Response:
# 1. Start
#
# 2. Define tasks as empty list
#
# 3. Define add_task():
#    a. Prompt user for task input
#    b. Append to tasks
#    c. Print confirmation
#
# 4. Define remove_task():
#    a. Prompt user for index
#    b. Validate index
#    c. If valid, delete task
#    d. Else, print error
#
# 5. Define list_tasks():
#    a. If empty, print message
#    b. Else, print each task with number
#
# 6. Define display_menu():
#    a. Print menu with 4 choices
#
# 7. Define get_user_choice():
#    a. Prompt user for choice
#    b. Validate if between 1–4
#    c. Return valid choice
#
# 8. Define main():
#    a. While True:
#      i. Show menu
#      ii. Get choice
#      iii. Call matching function
#      iv. If exit, break loop
#
# 9. Call main()
# **Course Reference:**
# "This refinement applied input validation techniques from Week 6, particularly the use of defensive programming to ensure safe user interaction."
#
#
# Second Refinement
# Refined Prompt:
# "Modify the pseudocode to include inline comments, doctest examples, and error handling with try/except for invalid inputs. Ensure all logic uses only basic Python concepts up to Week 10."
# AI Response:
# 1. Start
# 2. tasks = []  # list to hold task strings
# 3. Define add_task():
#    a. Ask user for task
#    b. Append to tasks
#    c. Print confirmation
#
# 4. Define remove_task():
#    a. Try:
#       i. Get index from user
#       ii. Convert to int
#       iii. If valid, remove task
#    b. Except:
#       i. Print error message
# 5. Define list_tasks():
#    a. If empty, say "no tasks"
#    b. Else, enumerate and print all
#
# 6. display_menu():
#    a. Print menu choices
#
# 7. get_user_choice():
#    a. Try input, check if valid (1-4)
#
# 8. main():
#    a. While True:
#       i. Show menu
#       ii. Get input
#       iii. Call correct function
#       iv. Break on exit
# **Course Reference:**
# "This refinement applied Week 8's basic error handling principles (try/except blocks), and Week 9's doctest formatting."
